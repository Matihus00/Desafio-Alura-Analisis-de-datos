# %% [markdown]
# <a href="https://colab.research.google.com/github/Matihus00/Desafio-Alura-Analisis-de-datos/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
tienda2.head()
# Out:
#            Producto  Categoría del Producto    Precio  Costo de envío  \
# 0  Silla de oficina                 Muebles  283600.0         15300.0
# 1         Pandereta  Instrumentos musicales   76800.0          2300.0
# 2         Cama king                 Muebles  443300.0         23800.0
# 3         Cama king                 Muebles  906200.0         46400.0
# 4  Silla de oficina                 Muebles  397800.0         19400.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      04/08/2021  Izabela de León        Medellín             1
# 1      26/11/2020   Blanca Ramirez        Medellín             3
# 2      22/10/2021  Izabela de León         Pereira             5
# 3      04/05/2022    Maria Alfonso            Cali             5
# 4      26/02/2022    Lucas Olivera          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0               Nequi                   1  6.25184 -75.56359
# ...

# %%
tienda3.head()
# Out:
#             Producto  Categoría del Producto     Precio  Costo de envío  \
# 0   Secadora de ropa       Electrodomésticos  1285100.0         66600.0
# 1      Mesa de noche                 Muebles   290100.0         13600.0
# 2  Guitarra acústica  Instrumentos musicales   303500.0         17400.0
# 3  Balón de voleibol    Deportes y diversión    58800.0          3300.0
# 4            Armario                 Muebles   521100.0         25900.0
#
#   Fecha de Compra        Vendedor Lugar de Compra  Calificación  \
# 0      17/12/2021   Camila Rivera     Santa Marta             4
# 1      10/02/2021   Maria Alfonso            Cali             3
# 2      22/01/2023   Lucas Olivera          Bogotá             5
# 3      22/03/2022     Pedro Gomez    Barranquilla             4
# 4      12/01/2022  Blanca Ramirez          Bogotá             1
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   4  11.24079 -74.19904
# ...

# %%
tienda4.head()
# Out:
#               Producto Categoría del Producto     Precio  Costo de envío  \
# 0         Lavavajillas      Electrodomésticos  1084800.0         56000.0
# 1             Cama box                Muebles   473800.0         25400.0
# 2  Balón de baloncesto   Deportes y diversión    23700.0             0.0
# 3  Modelado predictivo                 Libros    57700.0          1300.0
# 4          Auriculares           Electrónicos   138900.0          5600.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      11/11/2022    Rafael Acosta          Bogotá             4
# 1      03/01/2020  Izabela de León          Cúcuta             5
# 2      25/12/2022    Maria Alfonso        Medellín             5
# 3      23/11/2021    Lucas Olivera        Medellín             3
# 4      25/04/2022   Blanca Ramirez          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0  Tarjeta de crédito                   3  4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
totalFacturacion = tienda['Precio'].sum()
print(totalFacturacion)
totalFacturacion2 = tienda2['Precio'].sum()
print(totalFacturacion2)
totalFacturacion3 = tienda3['Precio'].sum()
print(totalFacturacion3)
totalFacturacion4 = tienda4['Precio'].sum()
print(totalFacturacion4)

Facturacion = [totalFacturacion, totalFacturacion2, totalFacturacion3, totalFacturacion4]
# Out:
# 1150880400.0
# 1116343500.0
# 1098019600.0
# 1038375700.0

# %% [markdown]
# # 2. Ventas por categoría

# %%
tienda["Categoría del Producto"].value_counts()
# Out:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64

# %%
tienda2["Categoría del Producto"].value_counts()
# Out:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64

# %%
tienda3["Categoría del Producto"].value_counts()
# Out:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Instrumentos musicales     177
# Artículos para el hogar    177
# Name: count, dtype: int64

# %%
tienda4["Categoría del Producto"].value_counts()
# Out:
# Categoría del Producto
# Muebles                    480
# Electrónicos               451
# Juguetes                   338
# Deportes y diversión       277
# Electrodomésticos          254
# Artículos para el hogar    201
# Libros                     187
# Instrumentos musicales     170
# Name: count, dtype: int64

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
promedio_calificacion = tienda['Calificación'].mean()
print(promedio_calificacion)
promedio_calificacion2 = tienda2['Calificación'].mean()
print(promedio_calificacion2)
promedio_calificacion3 = tienda3['Calificación'].mean()
print(promedio_calificacion3)
promedio_calificacion4 = tienda4['Calificación'].mean()
print(promedio_calificacion4)

opiniones = [promedio_calificacion, promedio_calificacion2, promedio_calificacion3, promedio_calificacion4]
# Out:
# 3.976685036032217
# 4.037303942348453
# 4.048325561678677
# 3.9957591178965224

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
Productos_Mas_Vendidos = tienda["Producto"].value_counts().idxmax()
Cantidad = tienda["Producto"].value_counts().max()
print(Productos_Mas_Vendidos, Cantidad)

Productos_Mas_Vendidos2 = tienda2["Producto"].value_counts().idxmax()
Cantidad2 = tienda2["Producto"].value_counts().max()
print(Productos_Mas_Vendidos2, Cantidad2)

Productos_Mas_Vendidos3 = tienda3["Producto"].value_counts().idxmax()
Cantidad3 = tienda3["Producto"].value_counts().max()
print(Productos_Mas_Vendidos3, Cantidad3)

Productos_Mas_Vendidos4 = tienda4["Producto"].value_counts().idxmax()
Cantidad4 = tienda4["Producto"].value_counts().max()
print(Productos_Mas_Vendidos4, Cantidad4)

Total_Productos_Mas_Vendidos = [Productos_Mas_Vendidos, Productos_Mas_Vendidos2, Productos_Mas_Vendidos3, Productos_Mas_Vendidos4]
Total_Cantidad_Mas_Vendidos = [Cantidad, Cantidad2, Cantidad3, Cantidad4]
# Out:
# Microondas 60
# Iniciando en programación 65
# Kit de bancas 57
# Cama box 62

# %%
productos_menos_vendidos = tienda["Producto"].value_counts().idxmin()
cantidad_menos_vendidos = tienda["Producto"].value_counts().min()
print(productos_menos_vendidos, cantidad_menos_vendidos)\

productos_menos_vendidos2 = tienda2["Producto"].value_counts().idxmin()
cantidad_menos_vendidos2 = tienda2["Producto"].value_counts().min()
print(productos_menos_vendidos2, cantidad_menos_vendidos2)

productos_menos_vendidos3 = tienda3["Producto"].value_counts().idxmin()
cantidad_menos_vendidos3 = tienda3["Producto"].value_counts().min()
print(productos_menos_vendidos3, cantidad_menos_vendidos3)

productos_menos_vendidos4 = tienda4["Producto"].value_counts().idxmin()
cantidad_menos_vendidos4 = tienda4["Producto"].value_counts().min()
print(productos_menos_vendidos4, cantidad_menos_vendidos4)
# Out:
# Auriculares con micrófono 33
# Juego de mesa 32
# Bloques de construcción 35
# Guitarra eléctrica 33

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
tienda_promedio_envio = tienda["Costo de envío"].mean().round(2)
print(tienda_promedio_envio)
tienda_promedio_envio2 = tienda2["Costo de envío"].mean().round(2)
print(tienda_promedio_envio2)
tienda_promedio_envio3 = tienda3["Costo de envío"].mean().round(2)
print(tienda_promedio_envio3)
tienda_promedio_envio4 = tienda4["Costo de envío"].mean().round(2)
print(tienda_promedio_envio4)
# Out:
# 26018.61
# 25216.24
# 24805.68
# 23459.46

# %%
promedio_envio = [tienda_promedio_envio, tienda_promedio_envio2, tienda_promedio_envio3, tienda_promedio_envio4]

# %%
tiendas = [tienda,tienda2,tienda3,tienda4]

for n,i in enumerate(tiendas, 1) :
  Costo_total_envio = i["Costo de envío"].sum()
  print(f"Tienda {n} tiene un costo total de envios: {Costo_total_envio}")
# Out:
# Tienda 1 tiene un costo total de envios: 61377900.0
# Tienda 2 tiene un costo total de envios: 59485100.0
# Tienda 3 tiene un costo total de envios: 58516600.0
# Tienda 4 tiene un costo total de envios: 55317400.0

# %% [markdown]
# # Graficos

# %% [markdown]
# ## Ingresos

# %%
import matplotlib.pyplot as plt

labels = ["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"]

plt.figure(figsize=(7,4))
plt.bar(labels, Facturacion)
plt.title("Ingreso total por tienda")
plt.xlabel("Tiendas")
plt.ylabel("Ingreso total")

plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# <a name= "grafico"> </a>
#
# ## Categoria por ventas

# %%
categoria_counts = tienda["Categoría del Producto"].value_counts()

plt.figure(figsize=(7,4))
plt.bar(categoria_counts.index, categoria_counts.values)
plt.title("Categorías de Productos Tienda 1")
plt.xlabel("Categoría")
plt.ylabel("Cantidad")
plt.xticks(rotation=70)
plt.show()

categoria_counts = tienda2["Categoría del Producto"].value_counts()

plt.figure(figsize=(7,4))
plt.bar(categoria_counts.index, categoria_counts.values)
plt.title("Categorías de Productos Tienda 2")
plt.xlabel("Categoría")
plt.ylabel("Cantidad")
plt.xticks(rotation=70)
plt.show()

# %%
categoria_counts = tienda3["Categoría del Producto"].value_counts()

plt.figure(figsize=(7,4))
plt.bar(categoria_counts.index, categoria_counts.values)
plt.title("Categorías de Productos Tienda 3")
plt.xlabel("Categoría")
plt.ylabel("Cantidad")
plt.xticks(rotation=70)
plt.show()

categoria_counts = tienda4["Categoría del Producto"].value_counts()

plt.figure(figsize=(7,4))
plt.bar(categoria_counts.index, categoria_counts.values)
plt.title("Categorías de Productos Tienda 4")
plt.xlabel("Categoría")
plt.ylabel("Cantidad")
plt.xticks(rotation=70)
plt.show()

# %% [markdown]
# <a name= "opinion"> </a>
# ## Opinion promedio por tienda

# %%
plt.figure(figsize=(6,6))
plt.pie(opiniones, labels=labels, autopct="%1.1f%%", startangle=90)
plt.title("Opinión promedio por tienda")
plt.show()

# %% [markdown]
# ## Producto mas vendido por tienda

# %%
import matplotlib.pyplot as plt

tiendas = ["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"]



plt.figure(figsize=(10,8))
plt.barh( tiendas,Total_Cantidad_Mas_Vendidos)
plt.title("Producto más vendido por tienda")
plt.xlabel("Cantidad vendida")

for i, (cantidad, producto) in enumerate(zip(Total_Cantidad_Mas_Vendidos, Total_Productos_Mas_Vendidos)):
    plt.text(cantidad + 0.2, i, producto)

plt.show()

# %% [markdown]
# <a name="envio" > </a>
# ## Costo de envio por tienda

# %%
labels= ["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"]

plt.figure(figsize =(8,6))
plt.bar(labels, promedio_envio)
plt.title("Costo de envio promedio por tienda")
plt.ylabel("Costo de envio")
plt.show()

# %% [markdown]
# # Informe Final

# %% [markdown]
# ## Analisis de Rendimiento de las Tiendas

# %% [markdown]
# El proposito de este analisis es evaluar el desempeño de las 4 tiendas del Sr Juan con el fin de determinar cual de ellas deberia ser vendida, para ello se realizo diferentes analisis y graficos que se detallaran a continuacion

# %% [markdown]
# ## Facturacion

# %% [markdown]
# Aqui nos encontramos con la tienda 1  destacando con un mayor indice de facturacion con un ingreseo de 1.150.880.400 y a la tienda 4 con el menor indice con 1.038.375.700

# %% [markdown]
# ## Ventas por Categoria

# %% [markdown]
# El informe nos da los siguientes numeros de que categorias son las mas vendidas en las tiendas
#
# Muebles	465<br>
# Electrónicos	448<br>
# Juguetes	324<br>
# Electrodomésticos	312<br>
# Deportes y diversión	284<br>
# Instrumentos musicales	182<br>
# Libros	173<br>
# Artículos para el hogar	171<br>
#
# tambien en los graficos que puede ver [aqui](#grafico)
# podra las ventas segun categoria en cada tienda y a futuro determinar tambien que en que tipos de productos seria conveniente invertir mas y en que otros menos

# %% [markdown]
# ## Calificaciones promedio por tienda

# %% [markdown]
# En esta seccion podremos ver que no hay mucha diferencia entre las tiendas destacando la tienda2 y la tienda3 por sobre las demas. Y a la tienda1 que apesar de tener la mayor facturacion tiene la peor calificacion de las 4
#
# puede ver la grafica [aqui](#opinion)

# %% [markdown]
# ## Productos mas vendidos y menos vendidos

# %% [markdown]
# Los productos más vendidos por tienda fueron:
#
# Tienda 1 → Microondas (60)
#
# Tienda 2 → Iniciando en programación (65)
#
# Tienda 3 → Kit de bancas (57)
#
# Tienda 4 → Cama box (62)
#
# Los productos menos vendidos:
#
# Tienda 1 → Auriculares con micrófono (33)
#
# Tienda 2 → Juego de mesa (32)
#
# Tienda 3 → Bloques de construcción (35)
#
# Tienda 4 → Guitarra eléctrica (33)
#
# En este aspecto podemos notar que las ventas de los productos se mantienen practicamente al mismo nivel en las 4 tiendas

# %% [markdown]
# ## Costo promedio de envios por tienda

# %% [markdown]
# en el siguiente grafico de [envios](#envio) podremos ver que la tienda1 tiene el costo promedio en envios mas elevado con 26018.61 y la tienda4 el menor con 23459.46

# %% [markdown]
# # Recomendacion final

# %% [markdown]
# dado lo datos anteriores podemos concluir que el local a vender debe ser la tienda4, si bien esta tienda destaca por tener una mayor puntuacion y un menor costo en envios, no es mucha la diferencia entre las otras tiendas y en contraparte es la que menor facturacion tiene, convirtiendola en la mejor opcion para ser vendida y reinvertir ya sea en un local nuevo o en invertir mas en productos que destacan en las demas tiendas

# %% [markdown]
# # Extra Venta por hubicacion

# %%
ventas_geo1 = tienda.groupby(["lat", "lon"]).size().reset_index(name="Cantidad_ventas")
ventas_geo1
# Out:
#          lat       lon  Cantidad_ventas
# 0   -4.21528 -69.94056               32
# 1    1.21361 -77.28111               23
# 2    2.92730 -75.28189                6
# 3    3.43722 -76.52250              283
# 4    3.86530 -67.92390                5
# 5    4.14200 -73.62664               11
# 6    4.53389 -75.68111               14
# 7    4.57937 -74.21682                5
# 8    4.60971 -74.08175              984
# 9    4.81333 -75.69611              133
# 10   5.06889 -75.51738               15
# 11   6.25184 -75.56359              563
# 12   7.12539 -73.11980               31
# 13   7.89391 -72.50782               51
# 14  10.39972 -75.51444               53
# 15  10.46314 -73.25322                3
# 16  10.96854 -74.78132               75
# 17  11.24079 -74.19904               32
# 18  11.54444 -72.90722               40

# %%
ventas_geo2 = tienda2.groupby(["lat", "lon"]).size().reset_index(name="Cantidad_ventas")
ventas_geo2
# Out:
#          lat       lon  Cantidad_ventas
# 0   -4.21528 -69.94056               34
# 1    1.21361 -77.28111               25
# 2    2.92730 -75.28189                6
# 3    3.43722 -76.52250              222
# 4    3.86530 -67.92390                2
# 5    4.14200 -73.62664                6
# 6    4.53389 -75.68111                4
# 7    4.57937 -74.21682                4
# 8    4.60971 -74.08175              985
# 9    4.81333 -75.69611              128
# 10   5.06889 -75.51738               13
# 11   6.25184 -75.56359              594
# 12   7.12539 -73.11980               50
# 13   7.89391 -72.50782               59
# 14  10.39972 -75.51444               70
# 15  10.46314 -73.25322                4
# 16  10.96854 -74.78132               78
# 17  11.24079 -74.19904               40
# 18  11.54444 -72.90722               35

# %%
ventas_geo3 = tienda3.groupby(["lat", "lon"]).size().reset_index(name="Cantidad_ventas")
ventas_geo3
# Out:
#          lat       lon  Cantidad_ventas
# 0   -4.21528 -69.94056               41
# 1    1.21361 -77.28111               16
# 2    2.92730 -75.28189               10
# 3    3.43722 -76.52250              248
# 4    3.86530 -67.92390                4
# 5    4.14200 -73.62664                5
# 6    4.53389 -75.68111                7
# 7    4.57937 -74.21682                6
# 8    4.60971 -74.08175              983
# 9    4.81333 -75.69611              134
# 10   5.06889 -75.51738                7
# 11   6.25184 -75.56359              580
# 12   7.12539 -73.11980               50
# 13   7.89391 -72.50782               44
# 14  10.39972 -75.51444               56
# 15  10.46314 -73.25322                3
# 16  10.96854 -74.78132               77
# 17  11.24079 -74.19904               44
# 18  11.54444 -72.90722               44

# %%
ventas_geo4 = tienda4.groupby(["lat", "lon"]).size().reset_index(name="Cantidad_ventas")
ventas_geo4
# Out:
#          lat       lon  Cantidad_ventas
# 0   -4.21528 -69.94056               35
# 1    1.21361 -77.28111               30
# 2    2.92730 -75.28189               18
# 3    3.43722 -76.52250              254
# 4    3.86530 -67.92390                3
# 5    4.14200 -73.62664                7
# 6    4.53389 -75.68111                3
# 7    4.57937 -74.21682                4
# 8    4.60971 -74.08175              991
# 9    4.81333 -75.69611              122
# 10   5.06889 -75.51738                6
# 11   6.25184 -75.56359              577
# 12   7.12539 -73.11980               50
# 13   7.89391 -72.50782               32
# 14  10.39972 -75.51444               63
# 15  10.46314 -73.25322                4
# 16  10.96854 -74.78132               80
# 17  11.24079 -74.19904               35
# 18  11.54444 -72.90722               44

# %%
import numpy as np

plt.figure(figsize=(8,6))

colores = {
    "Tienda 1": "red",
    "Tienda 2": "blue",
    "Tienda 3": "green",
    "Tienda 4": "purple"
}

for i, tienda_nombre in enumerate(colores.keys()):
    df_temp = df[df["Tienda"] == tienda_nombre]

    plt.figure(figsize=(6,4))
    plt.scatter(df_temp["lon"], df_temp["lat"], color=colores[tienda_nombre], alpha=0.7)
    plt.title(f"Distribución de ventas - {tienda_nombre}")
    plt.xlabel("Longitud")
    plt.ylabel("Latitud")
    plt.grid(True)
    plt.show()

# %%
# !pip install folium

# %%
tienda["Tienda"] = "Tienda 1"
tienda2["Tienda"] = "Tienda 2"
tienda3["Tienda"] = "Tienda 3"
tienda4["Tienda"] = "Tienda 4"

df = pd.concat([tienda, tienda2, tienda3, tienda4], ignore_index=True)

# %%
ventas_geo = df.groupby(["Tienda", "lat", "lon"]).size().reset_index(name="Cantidad_ventas")

# %%
import folium


mapa = folium.Map(location=[df["lat"].mean(), df["lon"].mean()], zoom_start=10)


for _, row in ventas_geo1.iterrows():
    folium.CircleMarker(
        location=[row["lat"], row["lon"]],
        radius=row["Cantidad_ventas"] * 0.1,
        popup=f"Tienda:  · Ventas: {row['Cantidad_ventas']}",

        fill=True,
        fill_opacity=0.35
    ).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
mapa = folium.Map(location=[df["lat"].mean(), df["lon"].mean()], zoom_start=10)


colores = {
    "Tienda 1": "red",
    "Tienda 2": "blue",
    "Tienda 3": "green",
    "Tienda 4": "purple"
}

for _, row in ventas_geo2.iterrows():
    folium.CircleMarker(
        location=[row["lat"], row["lon"]],
        radius=row["Cantidad_ventas"] * 0.1,
        popup=f"Tienda:  · Ventas: {row['Cantidad_ventas']}",

        fill=True,
        fill_opacity=0.35
    ).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
mapa = folium.Map(location=[df["lat"].mean(), df["lon"].mean()], zoom_start=10)


for _, row in ventas_geo3.iterrows():
    folium.CircleMarker(
        location=[row["lat"], row["lon"]],
        radius=row["Cantidad_ventas"] * 0.1,
        popup=f"Tienda:  · Ventas: {row['Cantidad_ventas']}",

        fill=True,
        fill_opacity=0.35
    ).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
mapa = folium.Map(location=[df["lat"].mean(), df["lon"].mean()], zoom_start=10)


for _, row in ventas_geo4.iterrows():
    folium.CircleMarker(
        location=[row["lat"], row["lon"]],
        radius=row["Cantidad_ventas"] * 0.1,
        popup=f"Tienda:  · Ventas: {row['Cantidad_ventas']}",

        fill=True,
        fill_opacity=0.35
    ).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...
